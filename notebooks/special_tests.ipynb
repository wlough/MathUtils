# %% [markdown]
# # `pymathutils.special` submodule tests

# %% [markdown]
# ## Spherical harmonics

# %%
import sys
from pathlib import Path

nb_dir = Path().resolve()
tests_dir = (nb_dir / ".." / "src" / "python").resolve()
sys.path.insert(0, str(tests_dir))

# %% [markdown]
# ### Compare MathUtils and SciPy implementations.

# %%
from spherical_harmonics_tests import run_mathutils_vs_scipy_tests


run_mathutils_vs_scipy_tests()
# Out:
# ----------------
# ----------------
#
# Testing pymathutils.Ylm against scipy.special.sph_harm_y with tol=1e-12, l_max=120
# ____________________
# test_scalar_Y_vs_Y
# Yfun1=<built-in method Ylm of pybind11_builtins.pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1 object at 0x7f797cebb910>
# Yfun2=<scipy.special._multiufuncs.MultiUFunc object at 0x7f7948319480>
# tol=1e-12
# l_max=120
# use_problem_angles=True
#
# testing l=120, m=120
# good up to l=120, m=120 (first 14641 spherical harmonics)
# ____________________
# test_Y_vs_Y
# Yfun1=<built-in method Ylm of pybind11_builtins.pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1 object at 0x7f797cebb910>
# Yfun2=<function sciYlm at 0x7f7947a3be20>
# tol=1e-12
# l_max=120
# use_problem_angles=True
#
# testing l=120, m=120
# good up to l=120, m=120 (first 14641 spherical harmonics)
# ____________________
# test_Y_vs_Y
# Yfun1=<built-in method real_Ylm of pybind11_builtins.pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1 object at 0x7f797cebb9f0>
# Yfun2=<function real_sciYlm at 0x7f7947a3bec0>
# tol=1e-12
# l_max=120
# use_problem_angles=True
#
# testing l=120, m=120
# good up to l=120, m=120 (first 14641 spherical harmonics)
# ____________________
# test_all_Y_vs_Y
# Yfun1=<built-in method compute_all_Ylm of pybind11_builtins.pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1 object at 0x7f794837f8b0>
# Yfun2=<function compute_all_sciYlm at 0x7f7947a3bf60>
# tol=1e-12
# l_max=120
# use_problem_angles=True
#
# testing l=120, m=120
# good up to l=120, m=120 (first 14641 spherical harmonics)
# ____________________
# test_all_Y_vs_Y
# Yfun1=<built-in method compute_all_real_Ylm of pybind11_builtins.pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1 object at 0x7f794837fa30>
# Yfun2=<function compute_all_real_sciYlm at 0x7f7947a84040>
# tol=1e-12
# l_max=120
# use_problem_angles=True
#
# testing l=120, m=120
# good up to l=120, m=120 (first 14641 spherical harmonics)
# ____________________
# time_all_mathutils_vs_scipy
# l_max=120
# use_problem_angles=True
#
# timeit sph_harm_y_all(l_max, l_max, Theta, Phi)
# 638 ms ± 1.47 ms per loop (mean ± std. dev. of 7 runs, 1 loops each)
# timeit compute_all_Ylm(l_max, ThetaPhi)
# 95.3 ms ± 336 µs per loop (mean ± std. dev. of 7 runs, 5 loops each)
# timeit compute_all_real_Ylm(l_max, ThetaPhi)
# 76.5 ms ± 330 µs per loop (mean ± std. dev. of 7 runs, 5 loops each)

# %% [markdown]
# ### Compare MathUtils and SymPy implementations with arbitrary precision.

# %%
from spherical_harmonics_tests import run_mathutils_vs_sympy_tests

run_mathutils_vs_sympy_tests(
    tol=1e-12,
    precision=20,
    l_max=20,
)
# Out:
# ----------------
# ----------------
#
# Testing pymathutils.Ylm against sympy.Ynm with tol=1e-12, precision=20, l_max=20
# ____________________
# test_Y_vs_Y
# Yfun1=<built-in method Ylm of pybind11_builtins.pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1 object at 0x7f797cebb910>
# Yfun2=<function run_mathutils_vs_sympy_tests.<locals>.<lambda> at 0x7f7947a85b20>
# tol=1e-12
# l_max=20
# use_problem_angles=True
#
# testing l=20, m=20
# good up to l=20, m=20 (first 441 spherical harmonics)

# %% [markdown]
# ### Compare SciPy and SymPy implementations with arbitrary precision.

# %%
from spherical_harmonics_tests import run_scipy_vs_sympy_tests

run_mathutils_vs_sympy_tests(
    tol=1e-12,
    precision=20,
    l_max=20,
)
