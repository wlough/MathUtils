# %% [markdown]
# # `pymathutils.random` submodule tests

# %% [markdown]
# ## Random number generator

# %%
import sys
from pathlib import Path

nb_dir = Path().resolve()
tests_dir = (nb_dir / ".." / "src" / "python").resolve()
sys.path.insert(0, str(tests_dir))

# %%
from pymathutils.random import RandomNumberGenerator

rng=RandomNumberGenerator()

rng.normal01()
rng.exponential(1)
# Out:
# 0.7162503419838475
